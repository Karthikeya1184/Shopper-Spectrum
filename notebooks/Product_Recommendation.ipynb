# %%
import pandas as pd

# %%
similarity = pd.read_csv(
    "../data/processed/product_similarity.csv",
    index_col=0
)

similarity.head()
# Out:
#                                 4 PURPLE FLOCK DINNER CANDLES  \
# Description
# 4 PURPLE FLOCK DINNER CANDLES                        1.000000
# 50'S CHRISTMAS GIFT BAG LARGE                        0.000000
# DOLLY GIRL BEAKER                                    0.000021
# I LOVE LONDON MINI BACKPACK                          0.000228
# I LOVE LONDON MINI RUCKSACK                          0.000000
#
#                                 50'S CHRISTMAS GIFT BAG LARGE  \
# Description
# 4 PURPLE FLOCK DINNER CANDLES                        0.000000
# 50'S CHRISTMAS GIFT BAG LARGE                        1.000000
# DOLLY GIRL BEAKER                                    0.003534
# I LOVE LONDON MINI BACKPACK                          0.004001
# I LOVE LONDON MINI RUCKSACK                          0.000000
#
#                                 DOLLY GIRL BEAKER  \
# Description
# 4 PURPLE FLOCK DINNER CANDLES            0.000021
# 50'S CHRISTMAS GIFT BAG LARGE            0.003534
# ...

# %%
product = similarity.index[0]

similarity[product].sort_values(
    ascending=False
).head(6)
# Out:
# Description
#  4 PURPLE FLOCK DINNER CANDLES        1.000000
# 4 PINK DINNER CANDLE SILVER FLOCK     0.664601
# PINK/FLOWER RABBIT EGG WARMER         0.402744
# 4 BLUE DINNER CANDLES SILVER FLOCK    0.362492
# GREEN WIRE STANDING CANDLE HOLDER     0.341820
# 12 IVORY ROSE PEG PLACE SETTINGS      0.313089
# Name:  4 PURPLE FLOCK DINNER CANDLES, dtype: float64

# %%
product = "WHITE HANGING HEART T-LIGHT HOLDER"

if product in similarity.index:

    similarity[product].sort_values(
        ascending=False
    ).iloc[1:6]

# %% [markdown]
# # Product Recommendation
#
# ### Business Insight
#
# The recommendation engine uses Item-Based Collaborative Filtering.
#
# Products that are frequently purchased by the same customers receive higher similarity scores.
#
# Business Benefits:
#
# - Cross-selling opportunities
# - Personalized shopping experience
# - Increased average order value
# - Improved customer satisfaction
